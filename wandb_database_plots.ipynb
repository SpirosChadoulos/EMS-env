# %% [markdown]
# # Creating Plots based on the collected experiment data in our WandB database

# %% [markdown]
# ## Importing libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## Reward mean figure - Resistant - PPO vs A2C - *100

# %%
data = pd.read_csv('data_csv/a2c_vs_ppo_resistant.csv')
# Remove unnecessary columns
data = data.iloc[:,[1,4]]
# Rename data columns
data.columns = ['PPO','A2C']
data
# Out:
#               PPO           A2C
# 0   -1.768361e+06 -1.760104e+06
# 1   -1.801651e+06 -1.805992e+06
# 2   -1.813765e+06 -1.834607e+06
# 3   -1.803109e+06 -1.844536e+06
# 4   -1.800788e+06 -1.844657e+06
# ..            ...           ...
# 189 -1.770103e+06 -1.602276e+06
# 190 -1.770377e+06 -1.602156e+06
# 191 -1.770229e+06           NaN
# 192 -1.770384e+06           NaN
# 193 -1.770372e+06           NaN
#
# [194 rows x 2 columns]

# %%
marker_every = 10
a2c_color = 'green'
ppo_color = 'blue'

# Create a plot and specify x and y
columns_to_plot = {
    'PPO': {'style': '-', 'marker': ',', 'markevery': marker_every, 'color': ppo_color, 'linewidth': 4},
    'A2C': {'style': '--', 'marker': ',', 'markevery': marker_every, 'color': a2c_color, 'linewidth': 4},
}

ax = data.plot(y=columns_to_plot.keys(), figsize=(20, 20))

# Increase font size for axis labels
ax.set_xlabel('Training Episode', fontsize=35, labelpad=25)
ax.set_ylabel('Episode Reward Mean', fontsize=35, labelpad=25)

# Increase font size for tick labels
ax.tick_params(axis='x', which='major', labelsize=32)
ax.tick_params(axis='y', which='major', labelsize=32)
ax.yaxis.offsetText.set_fontsize(24)

# Remove scientific notation
# ax.ticklabel_format(style='plain')


# Apply custom styles to each line in the plot
lines = ax.get_lines()
for col, style in columns_to_plot.items():
    line = lines[list(columns_to_plot.keys()).index(col)]
    line.set_linestyle(style['style'])
    line.set_marker(style['marker'])
    line.set_markevery(style['markevery'])
    line.set_color(style['color'])
    line.set_linewidth(style['linewidth'])
    #line.set_markersize(50)

# Customize the legend
legend = ax.legend(loc=2, prop={'size': 25}) 

plt.savefig('paper_plots/resistant_a2c_vs_ppo.png')
plt.show()

# %% [markdown]
# ## Reward mean figure - Receptive - PPO vs A2C - *100

# %%
data = pd.read_csv('data_csv/a2c_vs_ppo_receptive.csv')
# Remove unnecessary columns
data = data.iloc[:,[1,4]]
# Rename data columns
data.columns = ['PPO','A2C']
data
# Out:
#                PPO            A2C
# 0   -731707.367249 -735272.874147
# 1   -720682.663080 -732972.233129
# 2   -705396.844035 -738592.174300
# 3   -703582.224898 -730693.876427
# 4   -707830.913045 -734667.595641
# ..             ...            ...
# 189 -696722.567697            NaN
# 190 -696758.315348            NaN
# 191 -697167.834532            NaN
# 192 -697277.247535            NaN
# 193 -697437.032959            NaN
#
# [194 rows x 2 columns]

# %%
marker_every = 10
a2c_color = 'green'
ppo_color = 'blue'

# Create a plot and specify x and y
columns_to_plot = {
    'PPO': {'style': '-', 'marker': ',', 'markevery': marker_every, 'color': ppo_color, 'linewidth': 4},
    'A2C': {'style': '--', 'marker': ',', 'markevery': marker_every, 'color': a2c_color, 'linewidth': 4},
}

ax = data.plot(y=columns_to_plot.keys(), figsize=(20, 20))

# Increase font size for axis labels
ax.set_xlabel('Training Episode', fontsize=35, labelpad=25)
ax.set_ylabel('Episode Reward Mean', fontsize=35, labelpad=25)

# Increase font size for tick labels
ax.tick_params(axis='x', which='major', labelsize=32)
ax.tick_params(axis='y', which='major', labelsize=32)
ax.yaxis.offsetText.set_fontsize(24)

# Remove scientific notation
# ax.ticklabel_format(style='plain')


# Apply custom styles to each line in the plot
lines = ax.get_lines()
for col, style in columns_to_plot.items():
    line = lines[list(columns_to_plot.keys()).index(col)]
    line.set_linestyle(style['style'])
    line.set_marker(style['marker'])
    line.set_markevery(style['markevery'])
    line.set_color(style['color'])
    line.set_linewidth(style['linewidth'])
    #line.set_markersize(50)

# Customize the legend
legend = ax.legend(loc=2, prop={'size': 25}) 

plt.savefig('paper_plots/receptive_a2c_vs_ppo.png')
plt.show()

# %% [markdown]
# ## Reward mean figure - Neutral - PPO vs A2C - *100

# %%
data = pd.read_csv('data_csv/a2c_vs_ppo_neutral.csv')
# Remove unnecessary columns
data = data.iloc[:,[1,4]]
# Rename data columns
data.columns = ['PPO','A2C']
data
# Out:
#               PPO           A2C
# 0   -1.263033e+06 -1.217901e+06
# 1   -1.256010e+06 -1.281176e+06
# 2   -1.246822e+06 -1.299458e+06
# 3   -1.255888e+06 -1.322789e+06
# 4   -1.260655e+06 -1.335437e+06
# ..            ...           ...
# 189 -1.271210e+06 -1.125992e+06
# 190 -1.271161e+06 -1.125736e+06
# 191 -1.271023e+06 -1.125461e+06
# 192 -1.271193e+06 -1.125218e+06
# 193           NaN -1.124727e+06
#
# [194 rows x 2 columns]

# %%
marker_every = 10
a2c_color = 'green'
ppo_color = 'blue'

# Create a plot and specify x and y
columns_to_plot = {
    'PPO': {'style': '-', 'marker': ',', 'markevery': marker_every, 'color': ppo_color, 'linewidth': 4},
    'A2C': {'style': '--', 'marker': ',', 'markevery': marker_every, 'color': a2c_color, 'linewidth': 4},
}

ax = data.plot(y=columns_to_plot.keys(), figsize=(20, 20))

# Increase font size for axis labels
ax.set_xlabel('Training Episode', fontsize=35, labelpad=25)
ax.set_ylabel('Episode Reward Mean', fontsize=35, labelpad=25)

# Increase font size for tick labels
ax.tick_params(axis='x', which='major', labelsize=32)
ax.tick_params(axis='y', which='major', labelsize=32)
ax.yaxis.offsetText.set_fontsize(24)

# Remove scientific notation
# ax.ticklabel_format(style='plain')


# Apply custom styles to each line in the plot
lines = ax.get_lines()
for col, style in columns_to_plot.items():
    line = lines[list(columns_to_plot.keys()).index(col)]
    line.set_linestyle(style['style'])
    line.set_marker(style['marker'])
    line.set_markevery(style['markevery'])
    line.set_color(style['color'])
    line.set_linewidth(style['linewidth'])
    #line.set_markersize(50)

# Customize the legend
legend = ax.legend(loc=2, prop={'size': 25}) 

plt.savefig('paper_plots/neutral_a2c_vs_ppo.png')
plt.show()

# %% [markdown]
# ## Reward mean figure - Prudent - PPO vs A2C - *100

# %%
data = pd.read_csv('data_csv/a2c_vs_ppo_prudent.csv')
# Remove unnecessary columns
data = data.iloc[:,[1,4]]
# Rename data columns
data.columns = ['PPO','A2C']
data
# Out:
#               PPO           A2C
# 0   -1.005138e+06 -1.011863e+06
# 1   -9.678892e+05 -9.162416e+05
# 2   -9.677674e+05 -9.154178e+05
# 3   -9.703196e+05 -9.042609e+05
# 4   -9.707570e+05 -8.996784e+05
# ..            ...           ...
# 190 -9.328893e+05 -7.611869e+05
# 191 -9.329994e+05 -7.612445e+05
# 192 -9.327624e+05 -7.612138e+05
# 193 -9.326733e+05           NaN
# 194 -9.325721e+05           NaN
#
# [195 rows x 2 columns]

# %%
marker_every = 10
a2c_color = 'green'
ppo_color = 'blue'

# Create a plot and specify x and y
columns_to_plot = {
    'PPO': {'style': '-', 'marker': ',', 'markevery': marker_every, 'color': ppo_color, 'linewidth': 4},
    'A2C': {'style': '--', 'marker': ',', 'markevery': marker_every, 'color': a2c_color, 'linewidth': 4},
}

ax = data.plot(y=columns_to_plot.keys(), figsize=(20, 20))

# Increase font size for axis labels
ax.set_xlabel('Training Episode', fontsize=35, labelpad=25)
ax.set_ylabel('Episode Reward Mean', fontsize=35, labelpad=25)

# Increase font size for tick labels
ax.tick_params(axis='x', which='major', labelsize=32)
ax.tick_params(axis='y', which='major', labelsize=32)
ax.yaxis.offsetText.set_fontsize(24)

# Remove scientific notation
# ax.ticklabel_format(style='plain')


# Apply custom styles to each line in the plot
lines = ax.get_lines()
for col, style in columns_to_plot.items():
    line = lines[list(columns_to_plot.keys()).index(col)]
    line.set_linestyle(style['style'])
    line.set_marker(style['marker'])
    line.set_markevery(style['markevery'])
    line.set_color(style['color'])
    line.set_linewidth(style['linewidth'])
    #line.set_markersize(50)

# Customize the legend
legend = ax.legend(loc=2, prop={'size': 25}) 

plt.savefig('paper_plots/prudent_a2c_vs_ppo.png')
plt.show()

# %% [markdown]
# ## Reward mean figure - all user types - *100

# %%
data = pd.read_csv('data_csv/all_user_types_x100.csv')
# Remove unnecessary columns
data = data.iloc[:,[1,4,7,10]]
# Rename data columns
data.columns = ['Frugal','Neutral','Resistant','Receptive']
data
# Out:
#            Frugal       Neutral     Resistant      Receptive
# 0   -1.011863e+06 -1.217901e+06 -1.760104e+06 -735272.874147
# 1   -9.162416e+05 -1.281176e+06 -1.805992e+06 -732972.233129
# 2   -9.154178e+05 -1.299458e+06 -1.834607e+06 -738592.174300
# 3   -9.042609e+05 -1.322789e+06 -1.844536e+06 -730693.876427
# 4   -8.996784e+05 -1.335437e+06 -1.844657e+06 -734667.595641
# ..            ...           ...           ...            ...
# 189 -7.613938e+05 -1.125992e+06 -1.602276e+06            NaN
# 190 -7.611869e+05 -1.125736e+06 -1.602156e+06            NaN
# 191 -7.612445e+05 -1.125461e+06           NaN            NaN
# 192 -7.612138e+05 -1.125218e+06           NaN            NaN
# 193           NaN -1.124727e+06           NaN            NaN
#
# [194 rows x 4 columns]

# %%
marker_every = 10
prudent_color = 'green'
neutral_color = 'brown'
resistant_color = 'red'
receptive_color = 'blue'

# Create a plot and specify x and y
columns_to_plot = {
    'Frugal': {'style': '-', 'marker': ',','markevery': marker_every , 'color': prudent_color, 'linewidth': 4},
    'Neutral': {'style': '--', 'marker': ',','markevery': marker_every, 'color': neutral_color, 'linewidth': 4},
    'Resistant': {'style': '-', 'marker': 's','markevery': marker_every, 'color': resistant_color, 'linewidth': 4},
    'Receptive': {'style': '--', 'marker': 's','markevery': marker_every, 'color': receptive_color, 'linewidth': 4},
}

ax = data.plot(y = columns_to_plot.keys(),figsize=(20, 20))

# Increase font size for axis labels
ax.set_xlabel('Training Episode', fontsize=35, labelpad=25)
ax.set_ylabel('Episode Reward Mean', fontsize=35, labelpad=25)

# Increase font size for tick labels
ax.tick_params(axis='x', which='major', labelsize=32)
ax.tick_params(axis='y', which='major', labelsize=32)
ax.yaxis.offsetText.set_fontsize(24)

# Remove scientific notation
# ax.ticklabel_format(style='plain')


# Apply custom styles to each line in the plot
lines = ax.get_lines()
for col, style in columns_to_plot.items():
    line = lines[list(columns_to_plot.keys()).index(col)]
    line.set_linestyle(style['style'])
    line.set_marker(style['marker'])
    line.set_markevery(style['markevery'])
    line.set_color(style['color'])
    line.set_linewidth(style['linewidth'])
    line.set_markersize(15)

# Customize the legend
legend = ax.legend(loc=4, prop={'size': 25}) 

plt.savefig('paper_plots/user_types_X100.png')
plt.show()

# %% [markdown]
# ## Reward mean figure - all user types - 200

# %%
data = pd.read_csv('data_csv/all_user_types_200.csv')
# Remove unnecessary columns
data = data.iloc[:,[1,4,7,10]]
# Rename data columns
data.columns = ['Frugal','Neutral','Resistant','Receptive']
data
# Out:
#            Frugal       Neutral     Resistant     Receptive
# 0   -1.661292e+06 -1.924755e+06 -2.870650e+06 -1.083422e+06
# 1   -1.495503e+06 -2.014938e+06 -2.915244e+06 -1.078938e+06
# 2   -1.492833e+06 -2.047109e+06 -2.955097e+06 -1.087896e+06
# 3   -1.471213e+06 -2.083209e+06 -2.964799e+06 -1.080336e+06
# 4   -1.450822e+06 -2.099611e+06 -2.958112e+06 -1.084038e+06
# ..            ...           ...           ...           ...
# 189 -1.230189e+06 -1.676645e+06 -2.953563e+06 -8.438039e+05
# 190 -1.229560e+06 -1.676301e+06           NaN           NaN
# 191 -1.229392e+06 -1.675962e+06           NaN           NaN
# 192 -1.229174e+06           NaN           NaN           NaN
# 193 -1.229078e+06           NaN           NaN           NaN
#
# [194 rows x 4 columns]

# %%
marker_every = 10
prudent_color = 'green'
neutral_color = 'brown'
resistant_color = 'red'
receptive_color = 'blue'

# Create a plot and specify x and y
columns_to_plot = {
    'Frugal': {'style': '-', 'marker': ',','markevery': marker_every , 'color': prudent_color, 'linewidth': 4},
    'Neutral': {'style': '--', 'marker': ',','markevery': marker_every, 'color': neutral_color, 'linewidth': 4},
    'Resistant': {'style': '-', 'marker': 's','markevery': marker_every, 'color': resistant_color, 'linewidth': 4},
    'Receptive': {'style': '--', 'marker': 's','markevery': marker_every, 'color': receptive_color, 'linewidth': 4},
}

ax = data.plot(y = columns_to_plot.keys(),figsize=(20, 20))

# Increase font size for axis labels
ax.set_xlabel('Training Episode', fontsize=35, labelpad=25)
ax.set_ylabel('Episode Reward Mean', fontsize=35, labelpad=25)

# Increase font size for tick labels
ax.tick_params(axis='x', which='major', labelsize=32)
ax.tick_params(axis='y', which='major', labelsize=32)
ax.yaxis.offsetText.set_fontsize(24)

# Remove scientific notation
# ax.ticklabel_format(style='plain')


# Apply custom styles to each line in the plot
lines = ax.get_lines()
for col, style in columns_to_plot.items():
    line = lines[list(columns_to_plot.keys()).index(col)]
    line.set_linestyle(style['style'])
    line.set_marker(style['marker'])
    line.set_markevery(style['markevery'])
    line.set_color(style['color'])
    line.set_linewidth(style['linewidth'])
    line.set_markersize(15)

# Customize the legend
legend = ax.legend(loc=4, prop={'size': 25}) 

plt.savefig('paper_plots/user_types_200.png')
plt.show()

# %% [markdown]
# ## Reward mean figure - all user types - 100

# %%
data = pd.read_csv('data_csv/all_user_types_100.csv')
# Remove unnecessary columns
data = data.iloc[:,[1,4,7,10]]
# Rename data columns
data.columns = ['Frugal','Neutral','Resistant','Receptive']
data
# Out:
#            Frugal       Neutral     Resistant     Receptive
# 0   -1.661292e+06 -1.924755e+06 -2.870650e+06 -1.083422e+06
# 1   -1.495503e+06 -2.014938e+06 -2.915244e+06 -1.078938e+06
# 2   -1.492833e+06 -2.047109e+06 -2.955097e+06 -1.087896e+06
# 3   -1.471213e+06 -2.083209e+06 -2.964799e+06 -1.080336e+06
# 4   -1.450822e+06 -2.099611e+06 -2.958112e+06 -1.084038e+06
# ..            ...           ...           ...           ...
# 190 -1.136271e+06 -1.968699e+06           NaN -8.440606e+05
# 191 -1.136040e+06 -1.968373e+06           NaN           NaN
# 192 -1.135643e+06 -1.968251e+06           NaN           NaN
# 193 -1.135492e+06 -1.967440e+06           NaN           NaN
# 194 -1.135052e+06 -1.966941e+06           NaN           NaN
#
# [195 rows x 4 columns]

# %%
marker_every = 10
prudent_color = 'green'
neutral_color = 'brown'
resistant_color = 'red'
receptive_color = 'blue'

# Create a plot and specify x and y
columns_to_plot = {
    'Frugal': {'style': '-', 'marker': ',','markevery': marker_every , 'color': prudent_color, 'linewidth': 4},
    'Neutral': {'style': '--', 'marker': ',','markevery': marker_every, 'color': neutral_color, 'linewidth': 4},
    'Resistant': {'style': '-', 'marker': 's','markevery': marker_every, 'color': resistant_color, 'linewidth': 4},
    'Receptive': {'style': '--', 'marker': 's','markevery': marker_every, 'color': receptive_color, 'linewidth': 4},
}

ax = data.plot(y = columns_to_plot.keys(),figsize=(20, 20))

# Increase font size for axis labels
ax.set_xlabel('Training Episode', fontsize=35, labelpad=25)
ax.set_ylabel('Episode Reward Mean', fontsize=35, labelpad=25)

# Increase font size for tick labels
ax.tick_params(axis='x', which='major', labelsize=32)
ax.tick_params(axis='y', which='major', labelsize=32)
ax.yaxis.offsetText.set_fontsize(24)

# Remove scientific notation
# ax.ticklabel_format(style='plain')


# Apply custom styles to each line in the plot
lines = ax.get_lines()
for col, style in columns_to_plot.items():
    line = lines[list(columns_to_plot.keys()).index(col)]
    line.set_linestyle(style['style'])
    line.set_marker(style['marker'])
    line.set_markevery(style['markevery'])
    line.set_color(style['color'])
    line.set_linewidth(style['linewidth'])
    line.set_markersize(15)

# Customize the legend
legend = ax.legend(loc=4, prop={'size': 25}) 

plt.savefig('paper_plots/user_types_100.png')
plt.show()

# %% [markdown]
# ## Reward mean figure - all penalties - prudent

# %%
data = pd.read_csv('data_csv/mean_reward_all_penalties_prudent.csv')
# Remove unnecessary columns
data = data.iloc[:,[1,4,10]]
# Rename data columns
data.columns = ['A2C 100 100 1000','A2C 200 200 2000','A2C *100 *100 *1000']
data
# Out:
#      A2C 100 100 1000  A2C 200 200 2000  A2C *100 *100 *1000
# 0       -1.661292e+06     -1.661292e+06        -1.011863e+06
# 1       -1.495503e+06     -1.495503e+06        -9.162416e+05
# 2       -1.492833e+06     -1.492833e+06        -9.154178e+05
# 3       -1.471213e+06     -1.471213e+06        -9.042609e+05
# 4       -1.450822e+06     -1.450822e+06        -8.996784e+05
# ..                ...               ...                  ...
# 190     -1.136271e+06     -1.229560e+06        -7.611869e+05
# 191     -1.136040e+06     -1.229392e+06        -7.612445e+05
# 192     -1.135643e+06     -1.229174e+06        -7.612138e+05
# 193     -1.135492e+06     -1.229078e+06                  NaN
# 194     -1.135052e+06               NaN                  NaN
#
# [195 rows x 3 columns]

# %%
marker_every = 10
a2c_100_color = 'green'
a2c_200_color = 'brown'
a2c_x100_color = 'blue'

# Create a plot and specify x and y
columns_to_plot = {
    'A2C 100 100 1000': {'style': '-', 'marker': ',','markevery': marker_every , 'color': a2c_100_color, 'linewidth': 4},
    'A2C 200 200 2000': {'style': '--', 'marker': ',','markevery': marker_every, 'color': a2c_200_color, 'linewidth': 4},
    'A2C *100 *100 *1000': {'style': '--', 'marker': 'o','markevery': marker_every, 'color': a2c_x100_color, 'linewidth': 4},
}

ax = data.plot(y = columns_to_plot.keys(),figsize=(20, 20))

# Increase font size for axis labels
ax.set_xlabel('Training Episode', fontsize=35, labelpad=25)
ax.set_ylabel('Episode Reward Mean', fontsize=35, labelpad=25)

# Increase font size for tick labels
ax.tick_params(axis='x', which='major', labelsize=32)
ax.tick_params(axis='y', which='major', labelsize=32)
ax.yaxis.offsetText.set_fontsize(24)

# Remove scientific notation
# ax.ticklabel_format(style='plain')


# Apply custom styles to each line in the plot
lines = ax.get_lines()
for col, style in columns_to_plot.items():
    line = lines[list(columns_to_plot.keys()).index(col)]
    line.set_linestyle(style['style'])
    line.set_marker(style['marker'])
    line.set_markevery(style['markevery'])
    line.set_color(style['color'])
    line.set_linewidth(style['linewidth'])
    line.set_markersize(15)

# Customize the legend with LaTeX-formatted labels
latex_labels = [r'A2C ($\delta_d=100$ and $\delta^*=1000$)', r'A2C ($\delta_d=200$ and $\delta^*=2000$)', 
                r'A2C ($\delta_d=100\cdot{P^d}$ and $\delta^*=1000\cdot{P^d}$)']

ax.legend(latex_labels, loc=4, prop={'size': 25})


plt.savefig('paper_plots/reward_mean_penalties.png')
plt.show()

# %% [markdown]
# ## Cost figure - all penalties - prudent

# %%
data = pd.read_csv('data_csv/cost_all_penalties_prudent.csv')
# Remove unnecessary columns
data = data.iloc[:,[1,4,10]]
# Rename data columns
data.columns = ['A2C 100 100 1000','A2C 200 200 2000','A2C *100 *100 *1000']
data
# Out:
#      A2C 100 100 1000  A2C 200 200 2000  A2C *100 *100 *1000
# 0         4092.044289       4092.044289          4092.044289
# 1         3902.876919       3902.876919          3903.094319
# 2         4032.595649       4032.595649          4044.808273
# 3         4062.867123       4062.867123          4092.434067
# 4         4102.047535       4102.047535          4159.373810
# ..                ...               ...                  ...
# 190       3282.779046       3895.050350          4095.416306
# 191       3280.282335       3895.481691          4095.692343
# 192       3281.177234       3898.937025          4099.537334
# 193       3279.261335       3899.429890                  NaN
# 194       3276.735066               NaN                  NaN
#
# [195 rows x 3 columns]

# %%
marker_every = 10
a2c_100_color = 'green'
a2c_200_color = 'brown'
a2c_x100_color = 'blue'

# Create a plot and specify x and y
columns_to_plot = {
    'A2C 100 100 1000': {'style': '-', 'marker': ',','markevery': marker_every , 'color': a2c_100_color, 'linewidth': 4},
    'A2C 200 200 2000': {'style': '--', 'marker': ',','markevery': marker_every, 'color': a2c_200_color, 'linewidth': 4},
    'A2C *100 *100 *1000': {'style': '--', 'marker': 'o','markevery': marker_every, 'color': a2c_x100_color, 'linewidth': 4},
}

ax = data.plot(y = columns_to_plot.keys(),figsize=(20, 20))

# Set the axis labels
ax.set_xlabel('Training Episode', fontsize=35, labelpad=25)
ax.set_ylabel('Cost in Cents', fontsize=35, labelpad=25)

# Increase font size for tick labels
ax.tick_params(axis='x', which='major', labelsize=32)
ax.tick_params(axis='y', which='major', labelsize=32)
ax.yaxis.offsetText.set_fontsize(24)

# Remove scientific notation
# ax.ticklabel_format(style='plain')


# Apply custom styles to each line in the plot
lines = ax.get_lines()
for col, style in columns_to_plot.items():
    line = lines[list(columns_to_plot.keys()).index(col)]
    line.set_linestyle(style['style'])
    line.set_marker(style['marker'])
    line.set_markevery(style['markevery'])
    line.set_color(style['color'])
    line.set_linewidth(style['linewidth'])
    line.set_markersize(15)

# Customize the legend with LaTeX-formatted labels
latex_labels = [r'A2C ($\delta_d=100$ and $\delta^*=1000$)', r'A2C ($\delta_d=200$ and $\delta^*=2000$)', 
                r'A2C ($\delta_d=100\cdot{P^d}$ and $\delta^*=1000\cdot{P^d}$)']

ax.legend(latex_labels, loc=3, prop={'size': 25})


plt.savefig('paper_plots/prudent_cost_mean_penalties.png')
plt.show()

# %% [markdown]
# ## Cost figure - all user types - 100

# %%
data = pd.read_csv('data_csv/cost_all_users_100.csv')
# Remove unnecessary columns
data = data.iloc[:,[1,4,7,10]]
# Rename data columns
data.columns = ['Prudent','Neutral','Resistant','Receptive']
data
# Out:
#          Prudent       Neutral     Resistant     Receptive
# 0    4092.044289  11354.564533  10449.991814  13621.874147
# 1    3902.876919  11837.788722  10644.026226  13037.625140
# 2    4032.595649  12109.134379  10296.862329  13496.129153
# 3    4062.867123  12158.988018  10098.884962  13536.353155
# 4    4102.047535  12091.286255  10191.955518  13517.863789
# ..           ...           ...           ...           ...
# 190  3282.779046  11910.789742           NaN  13261.600955
# 191  3280.282335  11913.921505           NaN           NaN
# 192  3281.177234  11912.230205           NaN           NaN
# 193  3279.261335  11910.213993           NaN           NaN
# 194  3276.735066  11912.891288           NaN           NaN
#
# [195 rows x 4 columns]

# %%
marker_every = 10
prudent_color = 'green'
neutral_color = 'brown'
resistant_color = 'red'
receptive_color = 'blue'

# Create a plot and specify x and y
columns_to_plot = {
    'Prudent': {'style': '-', 'marker': ',','markevery': marker_every , 'color': prudent_color, 'linewidth': 4},
    'Neutral': {'style': '--', 'marker': ',','markevery': marker_every, 'color': neutral_color, 'linewidth': 4},
    'Resistant': {'style': '-', 'marker': 'o','markevery': marker_every, 'color': resistant_color, 'linewidth': 4},
    'Receptive': {'style': '--', 'marker': 'o','markevery': marker_every, 'color': receptive_color, 'linewidth': 4},
}

ax = data.plot(y = columns_to_plot.keys(),figsize=(20, 20))

# Set the axis labels
ax.set_xlabel('Training Episode', fontsize=35, labelpad=25)
ax.set_ylabel('Cost in Cents', fontsize=35, labelpad=25)

# Increase font size for tick labels
ax.tick_params(axis='x', which='major', labelsize=32)
ax.tick_params(axis='y', which='major', labelsize=32)
ax.yaxis.offsetText.set_fontsize(24)

# Remove scientific notation
# ax.ticklabel_format(style='plain')


# Apply custom styles to each line in the plot
lines = ax.get_lines()
for col, style in columns_to_plot.items():
    line = lines[list(columns_to_plot.keys()).index(col)]
    line.set_linestyle(style['style'])
    line.set_marker(style['marker'])
    line.set_markevery(style['markevery'])
    line.set_color(style['color'])
    line.set_linewidth(style['linewidth'])
    line.set_markersize(15)

    
ax.legend(loc=7, prop={'size': 25})    
    
plt.savefig('paper_plots/cost_mean_all_users.png')
plt.show()

# %% [markdown]
# ## Best Cost for Each User

# %%
data = pd.read_csv('data_csv/all_user_cost.csv')
# Remove unnecessary columns
data = data.iloc[:,[1,4,7,10]]
# Rename data columns
data.columns = ['Prudent','Neutral','Resistant','Receptive']
data
# Out:
#          Prudent       Neutral     Resistant     Receptive
# 0    4092.044289  11354.564533  10449.991814  13621.874147
# 1    3902.876919  11837.788722  10644.026226  13037.233129
# 2    4032.595649  12109.134379  10296.862329  13495.840966
# 3    4062.867123  12158.988018  10098.884962  13519.376427
# 4    4102.047535  12091.286255  10191.955518  13475.395641
# ..           ...           ...           ...           ...
# 190  3282.779046  10544.066907           NaN           NaN
# 191  3280.282335  10543.618092           NaN           NaN
# 192  3281.177234           NaN           NaN           NaN
# 193  3279.261335           NaN           NaN           NaN
# 194  3276.735066           NaN           NaN           NaN
#
# [195 rows x 4 columns]

# %%
marker_every = 10
prudent_color = 'green'
neutral_color = 'brown'
resistant_color = 'red'
receptive_color = 'blue'

# Create a plot and specify x and y
columns_to_plot = {
    'Prudent': {'style': '-', 'marker': ',','markevery': marker_every , 'color': prudent_color, 'linewidth': 4},
    'Neutral': {'style': '--', 'marker': ',','markevery': marker_every, 'color': neutral_color, 'linewidth': 4},
    'Resistant': {'style': '-', 'marker': 'o','markevery': marker_every, 'color': resistant_color, 'linewidth': 4},
    'Receptive': {'style': '--', 'marker': 'o','markevery': marker_every, 'color': receptive_color, 'linewidth': 4},
}

ax = data.plot(y = columns_to_plot.keys(),figsize=(20, 20))

# Set the axis labels
ax.set_xlabel('Training Episode', fontsize=35, labelpad=25)
ax.set_ylabel('Cost in Cents', fontsize=35, labelpad=25)

# Increase font size for tick labels
ax.tick_params(axis='x', which='major', labelsize=32)
ax.tick_params(axis='y', which='major', labelsize=32)
ax.yaxis.offsetText.set_fontsize(24)

# Remove scientific notation
# ax.ticklabel_format(style='plain')


# Apply custom styles to each line in the plot
lines = ax.get_lines()
for col, style in columns_to_plot.items():
    line = lines[list(columns_to_plot.keys()).index(col)]
    line.set_linestyle(style['style'])
    line.set_marker(style['marker'])
    line.set_markevery(style['markevery'])
    line.set_color(style['color'])
    line.set_linewidth(style['linewidth'])
    line.set_markersize(15)

# Customize the legend with LaTeX-formatted labels
latex_labels = [r'Prudent ($\delta_d=100$ and $\delta^*=1000$)', r'Neutral ($\delta_d=200$ and $\delta^*=2000$)', 
                r'Resistant ($\delta_d=200$ and $\delta^*=2000$)', r'Receptive ($\delta_d=100\cdot{P^d}$ and $\delta^*=1000\cdot{P^d}$)']

ax.legend(latex_labels, loc='best', prop={'size': 25})
    
#ax.legend(loc=7, prop={'size': 25})    
    
plt.savefig('paper_plots/best_cost_mean_users.png')
plt.show()
